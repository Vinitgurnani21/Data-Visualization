# %% [markdown]
# # **Welcome to Data Visualization Handson**

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the required dataset (Student.csv)
df_student = pd.read_csv(r'D:\Intellipaat\Datasets\student.csv')
df_student
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Exploratory data analysis

# %%
# Renaming 'race/ethnicity' column to 'ethnicity'
df_student.rename(columns={'race/ethnicity' : 'ethnicity'}, inplace=True)

# Renaming 'parental level of education' to 'parent's education'
df_student.rename(columns={'parental level of education' : "parent's education"}, inplace=True)

# Rename 'test preparation course' to 'preparation test'
df_student.rename(columns={'test preparation course' : 'preparation test'}, inplace=True)

# %%
# Creating 'total marks' column having sum of all scores
df_student['total score'] = df_student['math score'] + df_student['reading score'] + df_student['writing score']

# Creating 'percentage' column having mean of all scores
df_student['percentage'] = (df_student['total score']/3).round(2)

# %%
df_student
# Out:
#      gender ethnicity  parent's education         lunch preparation test  \
# 0    female   group B   bachelor's degree      standard             none
# 1    female   group C        some college      standard        completed
# 2    female   group B     master's degree      standard             none
# 3      male   group A  associate's degree  free/reduced             none
# 4      male   group C        some college      standard             none
# ..      ...       ...                 ...           ...              ...
# 995  female   group E     master's degree      standard        completed
# 996    male   group C         high school  free/reduced             none
# 997  female   group C         high school  free/reduced        completed
# 998  female   group D        some college      standard        completed
# 999  female   group D        some college  free/reduced             none
#
#      math score  reading score  writing score  total score  percentage
# ...

# %%
# Information of dataframe
df_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gender              1000 non-null   object
#  1   ethnicity           1000 non-null   object
#  2   parent's education  1000 non-null   object
#  3   lunch               1000 non-null   object
#  4   preparation test    1000 non-null   object
#  5   math score          1000 non-null   int64
#  6   reading score       1000 non-null   int64
#  7   writing score       1000 non-null   int64
#  8   total score         1000 non-null   int64
#  9   percentage          1000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 78.3+ KB

# %%
# Dimension of dataframe (No. of rows, No. of columns)
df_student.shape
# Out:
# (1000, 10)

# %%
# Desciption of numerical data in dataframe
df_student.describe()
# Out:
#        math score  reading score  writing score  total score   percentage
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    67.770580
# std      15.16308      14.600192      15.195657    42.771978    14.257311
# min       0.00000      17.000000      10.000000    27.000000     9.000000
# 25%      57.00000      59.000000      57.750000   175.000000    58.330000
# 50%      66.00000      70.000000      69.000000   205.000000    68.330000
# 75%      77.00000      79.000000      79.000000   233.000000    77.670000
# max     100.00000     100.000000     100.000000   300.000000   100.000000

# %%
# Check for the null values in dataframe
df_student.isna().sum()
# Out:
# gender                0
# ethnicity             0
# parent's education    0
# lunch                 0
# preparation test      0
# math score            0
# reading score         0
# writing score         0
# total score           0
# percentage            0
# dtype: int64

# %%
df_student
# Out:
#      gender ethnicity  parent's education         lunch preparation test  \
# 0    female   group B   bachelor's degree      standard             none
# 1    female   group C        some college      standard        completed
# 2    female   group B     master's degree      standard             none
# 3      male   group A  associate's degree  free/reduced             none
# 4      male   group C        some college      standard             none
# ..      ...       ...                 ...           ...              ...
# 995  female   group E     master's degree      standard        completed
# 996    male   group C         high school  free/reduced             none
# 997  female   group C         high school  free/reduced        completed
# 998  female   group D        some college      standard        completed
# 999  female   group D        some college  free/reduced             none
#
#      math score  reading score  writing score  total score  percentage
# ...

# %% [markdown]
# ### Frequency

# %%
# 1
df_student['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# 2
df_student['ethnicity'].value_counts()
# Out:
# ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# 3
df_student['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
# 4
df_student['parent\'s education'].value_counts()
# Out:
# parent's education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# 5
df_student['preparation test'].value_counts()
# Out:
# preparation test
# none         642
# completed    358
# Name: count, dtype: int64

# %%
male = df_student[df_student['gender'] == 'male']
female = df_student[df_student['gender'] == 'female']

# %%
# 6

print(f"{'-'*5}  Math Score  {'-'*5}")
print("males :", round(male['math score'].mean(), 3))
print("females :", round(female['math score'].mean(), 3))

print()

print(f"{'-'*5}  Reading Score  {'-'*5}")
print("males :", round(male['reading score'].mean(), 3))
print("females :", round(female['reading score'].mean(), 3))

print()

print(f"{'-'*5}  Writing Score  {'-'*5}")
print("males :", round(male['writing score'].mean(), 3))
print("females :", round(female['writing score'].mean(), 3))
# Out:
# -----  Math Score  -----
# males : 68.728
# females : 63.633
#
# -----  Reading Score  -----
# males : 65.473
# females : 72.608
#
# -----  Writing Score  -----
# males : 63.311
# females : 72.467

# %%
# Inferences :- 
# 1. Females are more than males in numbers.

# 2. Group C has highest participation, group A has lowest participation.

# 3. More than 60% of students can afford standard lunch, rest of students can't afford.

# 4. There are only few parent's who've done master's degree(6%) & there double amount holds bachelor's(12%). 
#    Assumption by analysis :- Means the majority of parents are not well educated.

# 5. More than half number of students(64%) didin't give preparation test, which tells that it is completely
#    waste of time.

# 6. Males are performing better than females in Math, 
#    Females overtaken them in reading & writing perspective.

# %%
# Top 5 scorers (total score) in dataframe.
top_scores = pd.DataFrame(df_student.sort_values(by=['total score'], ascending=False))
top_scores
# Out:
#      gender ethnicity  parent's education         lunch preparation test  \
# 916    male   group E   bachelor's degree      standard        completed
# 458  female   group E   bachelor's degree      standard             none
# 962  female   group E  associate's degree      standard             none
# 114  female   group E   bachelor's degree      standard        completed
# 179  female   group D    some high school      standard        completed
# ..      ...       ...                 ...           ...              ...
# 76     male   group E    some high school      standard             none
# 327    male   group A        some college  free/reduced             none
# 596    male   group B         high school  free/reduced             none
# 980  female   group B         high school  free/reduced             none
# 59   female   group C    some high school  free/reduced             none
#
#      math score  reading score  writing score  total score  percentage
# ...

# %% [markdown]
# ### Data Visualization

# %%
# Count sub plots

# Grid
sns.set_style(style='darkgrid')

# No. of plots & Dimensions
fi, axs = plt.subplots(1, 2, figsize=(20, 7))

# Plot
sns.countplot(x='gender', data=df_student, ax=axs[0], hue='gender', palette='Dark2')
sns.countplot(x="ethnicity", data=df_student, ax=axs[1], hue='ethnicity', palette='magma', 
              order=['group A', 'group B', 'group C', 'group D', 'group E'])

# Show
plt.show()

# %%
# Histogram of math score

# Grid
sns.set_style(style='darkgrid')

# Plot
sns.histplot(df_student['math score'], bins=30, color='red', kde=True)

# Show
plt.show()

# By ploting the graph shows that it is normally distributed.

# %%
# Joint plot for reading score & writing score

# Plot
sns.jointplot(x='reading score', y='writing score', data=df_student, kind='reg')

# Show
plt.show()

# %%
# Pie plot for ethnicity

# Data
ethnicity_count = df_student['ethnicity'].value_counts()

# Plot
plt.pie(ethnicity_count, labels=ethnicity_count.index, autopct='%1.1f%%', radius=1.2)

# Show
plt.show()

# %% [markdown]
# END of Student.csv

# %% [markdown]
# ---

# %%
# Import the required dataset (cars.csv)
df_cars = pd.read_csv(r'D:\Intellipaat\Datasets\Cars.csv')
df_cars
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %% [markdown]
# ### Analyse Dataframe (before editing)

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %% [markdown]
# ### Edit Dataframe

# %%
df_cars['cubicinches'] = pd.to_numeric(df_cars['cubicinches'], errors='coerce')
df_cars['weightlbs'] = pd.to_numeric(df_cars['weightlbs'], errors='coerce')

# %% [markdown]
# ### Analyse Dataframe (after editing)

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# ### Data Visualization

# %%
# Create scatter plot for the following data, make sure all the plot apear in the same plane with x-label & y-label evenly spaced
# 1.. 'hp' & 'mpg'
# 2.. 'hp' & 'time-to-60'
# 3.. 'hp' & 'weightlbs'
# 4.. 'hp' & 'cylinders'

fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. 'hp' & 'mpg'
plt.subplot(2, 2, 1)
sns.scatterplot(x='hp', y='mpg', data=df_cars)
plt.xlabel('horse power')
plt.ylabel('miles per gallon')
plt.title('hp & mpg')

# 2 'hp' & 'time-to-60'
plt.subplot(2, 2, 2)
sns.scatterplot(x='hp', y='time-to-60', data=df_cars)
plt.xlabel('horse power')
plt.ylabel('time-to-60')
plt.title('hp & time-to-60')

# 3 'hp' & 'weightlbs'
plt.subplot(2, 2, 3)
sns.scatterplot(x='hp', y='weightlbs', data=df_cars)
plt.xlabel('horse power')
plt.ylabel('weightlbs')
plt.title('hp & weightlbs')

# 4 'hp' & 'cylinders'
plt.subplot(2, 2, 4)
sns.scatterplot(x='hp', y='cylinders', data=df_cars)
plt.xlabel('horse power')
plt.ylabel('cylinders')
plt.title('hp & cylinders')

plt.show()

# %%
# Create scatter plot for following data with respect to each brand.
# 1.. 'mpg' & 'hp'
# 2.. 'mpg' & 'weight'
# 3.. 'hp' & 'mpg'
# 4.. 'hp' & 'time-to-60'

fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. 'mpg' & 'hp'
plt.subplot(2, 2, 1)
sns.scatterplot(x='mpg', y='hp', data=df_cars, hue='brand')
plt.title('mpg & hp')

# 2. 'mpg' & 'weight'
plt.subplot(2, 2, 2)
sns.scatterplot(x='mpg', y='weightlbs', data=df_cars, hue='brand')
plt.title('mpg & weight')

# 3. 'hp' & 'mpg'
plt.subplot(2, 2, 3)
sns.scatterplot(x='hp', y='mpg', data=df_cars, hue='brand')
plt.title('hp & mpg')

# 4. 'hp' & 'time-to-60'
plt.subplot(2, 2, 4)
sns.scatterplot(x='hp', y='time-to-60', data=df_cars, hue='brand')
plt.title('hp & time-to-60')

plt.show()

# %%
# Create bar plot for the following, make sure all the plots appear in same plane with x-axis & y-axis evenly spaced.
# 1.. cylinder & horsepower, cylinders & miles per gallon, cylinders and weight.
# 2.. year & time-to-60, year & miles per gallon, year & horsepower.

fig, axes = plt.subplots(3, 2, figsize = (20, 20))

# 1. cylinder & horsepower
plt.subplot(3, 2, 1)
sns.barplot(x='cylinders', y='hp', data=df_cars)
plt.title('Cylinders & Horsepower')
plt.xlabel('Cylinders')
plt.ylabel('Horsepower')

# 2. cylinders & miles per gallon
plt.subplot(3, 2, 2)
sns.barplot(x='cylinders', y='mpg', data=df_cars)
plt.title('Cylinders & Miles per gallon')
plt.xlabel('Cylinders')
plt.ylabel('Miles per gallon')

# 3. cylinders and weightlbs
plt.subplot(3, 2, 3)
sns.barplot(x='cylinders', y='weightlbs', data=df_cars)
plt.title('Cylinders & Weightlbs')
plt.xlabel('Cylinders')
plt.ylabel('Weightlbs')

# 4. year & time-to-60
plt.subplot(3, 2, 4)
sns.barplot(x='year', y='time-to-60', data=df_cars)
plt.title('Year & Time-to-60')
plt.xlabel('Year')
plt.ylabel('Time-to-60')

# 5. year & miles per gallon
plt.subplot(3, 2, 5)
sns.barplot(x='year', y='mpg', data=df_cars)
plt.title('Year & Miles per gallon')
plt.xlabel('Year')
plt.ylabel('Miles per gallon')

# 6. year & horsepower
plt.subplot(3, 2, 6)
sns.barplot(x='year', y='hp', data=df_cars)
plt.title('Year & Horsepower')
plt.xlabel('Year')
plt.ylabel('Horsepower')

plt.show()

# %%
# Create bar plot for the following that shows the visual representation for each brands
# 1.. hp & cylinders
# 2.. mpg & cylinders
# 3.. weightlbs & cylinders
# 4.. time-to-60 & cylinders

fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. 'hp' & 'cylinders'
plt.subplot(2, 2, 1)
sns.barplot(x='cylinders', y='hp', data=df_cars, hue='brand')
plt.title('Horsepower & Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Horsepower')

# 2. 'mpg' & 'cylinders'
plt.subplot(2, 2, 2)
sns.barplot(x='cylinders', y='mpg', data=df_cars, hue='brand')
plt.title('Miles per gallon & Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Miles per gallon')

# 3. 'weightlbs' & 'cylinders'
plt.subplot(2, 2, 3)
sns.barplot(x='cylinders', y='weightlbs', data=df_cars, hue='brand')
plt.title('Weightlbs & Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Weightlbs')

# 4. 'time-to-60' & 'cylinders'
plt.subplot(2, 2, 4)
sns.barplot(x='cylinders', y='time-to-60', data=df_cars, hue='brand')
plt.title('Time-to-60 & Cylinders')
plt.xlabel('Cylinders')
plt.ylabel('Time-to-60')

plt.show()

# %%
# Create bar plot for the following that shows the visual representation for each brands
# 1.. hp & year
# 2.. mpg & year
# 3.. weightlbs & year
# 4.. time-to-60 & year

fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. 'hp' & 'year'
plt.subplot(2, 2, 1)
sns.barplot(x='year', y='hp', data=df_cars, hue='brand')
plt.title('Horsepower & Year')
plt.xlabel('Year')
plt.ylabel('Horsepower')

# 2. 'mpg' & 'year'
plt.subplot(2, 2, 2)
sns.barplot(x='year', y='mpg', data=df_cars, hue='brand')
plt.title('Miles per gallon & Year')
plt.xlabel('Year')
plt.ylabel('Miles per gallon')

# 3. 'weightlbs' & 'year'
plt.subplot(2, 2, 3)
sns.barplot(x='year', y='weightlbs', data=df_cars, hue='brand')
plt.title('Weightlbs & Year')
plt.xlabel('Year')
plt.ylabel('Weightlbs')

# 4. 'time-to-60' & 'year'
plt.subplot(2, 2, 4)
sns.barplot(x='year', y='time-to-60', data=df_cars, hue='brand')
plt.title('Time-to-60 & Year')
plt.xlabel('Year')
plt.ylabel('Time-to-60')

plt.show()

# %%
# Create box plot for the columns hp, mpg, time-to-60, and weightlbs
    
fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. hp
plt.subplot(2, 2, 1)
sns.boxplot(df_cars['hp'])
plt.title('Horsepower')

# 2. mpg
plt.subplot(2, 2, 2)
sns.boxplot(df_cars['mpg'])
plt.title('Miles per gallon')

# 3. time-to-60
plt.subplot(2, 2, 3)
sns.boxplot(df_cars['time-to-60'])
plt.title('Time-to-60')

# 4. weightlbs
plt.subplot(2, 2, 4)
sns.boxplot(df_cars['weightlbs'])
plt.title('Weightlbs')

plt.show()

# %%
# Create box plot for the columns hp, mpg, time-to-60, and weightlbs with respect to cylinders for each brand.

fig, axes = plt.subplots(2, 2, figsize = (20, 15))

# 1. hp vs cylinders
plt.subplot(2, 2, 1)
sns.boxplot(x='cylinders', y='hp', data=df_cars, hue='brand')
plt.title('Horsepower vs Cylinders')

# 2. mpg vs cylinders
plt.subplot(2, 2, 2)
sns.boxplot(x='cylinders', y='mpg', data=df_cars, hue='brand')
plt.title('Miles per gallon vs Cylinders')

# 3. time-to-60 vs cylinders
plt.subplot(2, 2, 3)
sns.boxplot(x='cylinders', y='time-to-60', data=df_cars, hue='brand')
plt.title('Time-to-60 vs Cylinders')

# 4. weightlbs vs cylinders
plt.subplot(2, 2, 4)
sns.boxplot(x='cylinders', y='weightlbs', data=df_cars, hue='brand')
plt.title('Weightlbs vs Cylinders')

plt.show()

# %%
# Create pair plots for the entire data to study various patterns in the data.

sns.pairplot(data=df_cars)
plt.show()

# %%
# Create pair plots for the entire data for each brand to study various patterns in the data.

sns.pairplot(data=df_cars, hue='brand')

# %%
# Create a heatmap for entire data to study correlation between each of the columns.

# For heatmap purpose
correlation = df_cars.corr(numeric_only=True)

# Plot
sns.heatmap(data=correlation, annot=True, cmap='crest')

# Label
plt.title("Correlation between columns")

# Show
plt.show()

# %%
# Create histogram plot for each column of the data to understand the distribution.

fig, axes = plt.subplots(4, 2, figsize=(20, 25))

# mpg
plt.subplot(4, 2, 1)
sns.histplot(x=df_cars['mpg'])
plt.title('Miles per gallon')

# cylinders
plt.subplot(4, 2, 2)
sns.histplot(x=df_cars['cylinders'])
plt.title('Cylinders')

# cubicinches
plt.subplot(4, 2, 3)
sns.histplot(x=df_cars['cubicinches'])
plt.title('Cubicinches')

# hp
plt.subplot(4, 2, 4)
sns.histplot(x=df_cars['hp'])
plt.title('Horse power')

# weightlbs
plt.subplot(4, 2, 5)
sns.histplot(x=df_cars['weightlbs'])
plt.title('Wightlbs')

# time-to-60
plt.subplot(4, 2, 6)
sns.histplot(x=df_cars['time-to-60'])
plt.title('Time-to-60')

# year
plt.subplot(4, 2, 7)
sns.histplot(x=df_cars['year'])
plt.title('Year')

# brand
plt.subplot(4, 2, 8)
sns.histplot(x=df_cars['brand'])
plt.title('Brand')

plt.show()

# %%
# Create histogram plot for each column of the data with respect to brand to understand the distribution.

fig, axes = plt.subplots(4, 2, figsize=(20, 25))

# mpg
plt.subplot(4, 2, 1)
sns.histplot(x=df_cars['mpg'], hue=df_cars['brand'])
plt.title('Miles per gallon')

# cylinders
plt.subplot(4, 2, 2)
sns.histplot(x=df_cars['cylinders'], hue=df_cars['brand'])
plt.title('Cylinders')

# cubicinches
plt.subplot(4, 2, 3)
sns.histplot(x=df_cars['cubicinches'], hue=df_cars['brand'])
plt.title('Cubicinches')

# hp
plt.subplot(4, 2, 4)
sns.histplot(x=df_cars['hp'], hue=df_cars['brand'])
plt.title('Horse power')

# weightlbs
plt.subplot(4, 2, 5)
sns.histplot(x=df_cars['weightlbs'], hue=df_cars['brand'])
plt.title('Wightlbs')

# time-to-60
plt.subplot(4, 2, 6)
sns.histplot(x=df_cars['time-to-60'], hue=df_cars['brand'])
plt.title('Time-to-60')

# year
plt.subplot(4, 2, 7)
sns.histplot(x=df_cars['year'], hue=df_cars['brand'])
plt.title('Year')

# brand
plt.subplot(4, 2, 8)
sns.histplot(x=df_cars['brand'], hue=df_cars['brand'])
plt.title('Brand')

plt.show()

# %% [markdown]
# END

# %% [markdown]
# ---
